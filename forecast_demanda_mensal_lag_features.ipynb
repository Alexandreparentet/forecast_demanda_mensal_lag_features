# %%
# Projeto: Previsão de Demanda Mensal por Produto com Lags
# Autor: Alexandre Teixeira
# Descrição: Este notebook realiza a previsão da demanda mensal de produtos por fornecedor,
#            utilizando atributos de atraso (lags) e modelos de regressão com validação temporal.
#            A previsão é feita para o próximo mês com base na demanda dos dois meses anteriores.
# Dataset: orders_2.csv, orders_products_2.csv, prices_2.csv
# Data da última atualização: Maio/2026

import pandas as pd
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.metrics import make_scorer, mean_absolute_error

# === 1. Carregamento dos dados ===
orders = pd.read_csv('/content/drive/MyDrive/novas_tabelas_2/orders_2.csv', parse_dates=['data_pedido'])
order_products = pd.read_csv('/content/drive/MyDrive/novas_tabelas_2/orders_products_2.csv', parse_dates=['data_preco'])
prices = pd.read_csv('/content/drive/MyDrive/novas_tabelas_2/prices_2.csv')

# === 2. Merge dos dados ===
merged = order_products.merge(
    orders[['id', 'data_pedido']],
    left_on='id_pedido',
    right_on='id',
    how='inner'
)
merged = merged.merge(prices[['id_preco', 'valor']], on='id_preco', how='left')

# === 3. Agregação mensal e Correção de Meses Faltantes ===
merged['order_month'] = merged['data_pedido'].dt.to_period('M')
demand_prod_month = (
    merged.groupby(['id_produto_fornecedor', 'order_month'])['quantidade']
    .sum()
    .reset_index(name='monthly_quantity')
)

all_products = demand_prod_month['id_produto_fornecedor'].unique()
all_months = pd.period_range(start=demand_prod_month['order_month'].min(), end=demand_prod_month['order_month'].max(), freq='M')
idx = pd.MultiIndex.from_product([all_products, all_months], names=['id_produto_fornecedor', 'order_month'])

demand_prod_month = demand_prod_month.set_index(['id_produto_fornecedor', 'order_month']).reindex(idx, fill_value=0).reset_index()

# === 4. Criação de features de lag ===
demand_prod_month = demand_prod_month.sort_values(['id_produto_fornecedor', 'order_month'])
demand_prod_month['prev_month_quantity'] = demand_prod_month.groupby('id_produto_fornecedor')['monthly_quantity'].shift(1)
demand_prod_month['prev2_month_quantity'] = demand_prod_month.groupby('id_produto_fornecedor')['monthly_quantity'].shift(2)

# Dropar as primeiras linhas de cada produto onde os lags são estritamente NaN (não temos histórico completo)
demand_prod_month = demand_prod_month.dropna(subset=['prev_month_quantity', 'prev2_month_quantity'])

# === 5. Preparação para modelagem ===
# IMPORTANTE: Para TimeSeriesSplit funcionar por tempo, o DataFrame precisa estar ordenado por tempo, não por produto!
df_time_ordered = demand_prod_month.sort_values('order_month')
X = df_time_ordered[['prev_month_quantity', 'prev2_month_quantity']]
y = df_time_ordered['monthly_quantity']

# === 6. Validação com Time Series Split ===
tscv = TimeSeriesSplit(n_splits=3)
mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# === 7. Pipelines de modelos ===
pipeline_ridge = Pipeline([('scaler', StandardScaler()), ('ridge', Ridge(alpha=1.0, random_state=42))])
pipeline_rf = Pipeline([('scaler', StandardScaler()), ('rf', RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1))])
pipeline_hgb = Pipeline([('scaler', StandardScaler()), ('hgb', HistGradientBoostingRegressor(random_state=42))])

# === 8. Avaliação dos modelos ===
models = {'Ridge': pipeline_ridge, 'RandomForest': pipeline_rf, 'HistGradientBoosting': pipeline_hgb}
results = {}

for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=tscv, scoring=mae_scorer)
    results[name] = (-scores.mean(), scores.std())

print("\nDesempenho (MAE) dos modelos (Validação Temporal Corrigida):")
for name, (mean_mae, std_mae) in results.items():
    print(f"{name}: MAE = {mean_mae:.2f} ± {std_mae:.2f}")

# === 9. Treinamento final ===
# Treina com todos os dados estruturados no formato correto
pipeline_hgb.fit(X, y)

# === 10. Preparar entrada para previsão ===
last_month = demand_prod_month['order_month'].max()
next_month = last_month + 1

# usa exatamente a quantidade real do último mês (Lag 1) e do penúltimo (Lag 2).
latest_data = demand_prod_month[demand_prod_month['order_month'] == last_month]

prediction_input = pd.DataFrame({
    'id_produto_fornecedor': latest_data['id_produto_fornecedor'],
    'prev_month_quantity': latest_data['monthly_quantity'],         # O mês atual vira o Lag 1 do futuro
    'prev2_month_quantity': latest_data['prev_month_quantity']      # O Lag 1 atual vira o Lag 2 do futuro
})

X_predict = prediction_input[['prev_month_quantity', 'prev2_month_quantity']]
predicted = pipeline_hgb.predict(X_predict)

predictions_df = pd.DataFrame({
    'id_produto_fornecedor': prediction_input['id_produto_fornecedor'],
    'mes_previsao': next_month.strftime('%Y-%m'),
    'demanda_prevista': np.maximum(0, predicted.round(0)).astype(int) # Evita previsões negativas absurdas
})

print(f"\nPrevisões para {next_month.strftime('%B de %Y')}:\n")
print(predictions_df.to_string(index=False))
